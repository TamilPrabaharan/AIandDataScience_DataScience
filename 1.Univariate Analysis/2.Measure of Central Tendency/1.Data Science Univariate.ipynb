# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv("Placement.CSV")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.columns
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'salary'],
#       dtype='object')

# %%
dir(dataset)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
dataset['ssc_b'].dtypes
# Out:
# dtype('O')

# %%
dataset['ssc_p'].dtypes
# Out:
# dtype('float64')

# %% [markdown]
# # Quan Qual

# %%
from Univariate import Univariate

# %%
Univariate.QuanQual(dataset)
# Out:
# sl_no
# gender
# ssc_p
# ssc_b
# hsc_p
# hsc_b
# hsc_s
# degree_p
# degree_t
# workex
# etest_p
# specialisation
# mba_p
# status
# salary
# (['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary'],
#  ['gender',
#   'ssc_b',
#   'hsc_b',
#   'hsc_s',
#   'degree_t',
#   'workex',
#   'specialisation',
#   'status'])

# %%
Quan,Qual=Univariate.QuanQual(dataset)
# Out:
# sl_no
# gender
# ssc_p
# ssc_b
# hsc_p
# hsc_b
# hsc_s
# degree_p
# degree_t
# workex
# etest_p
# specialisation
# mba_p
# status
# salary

# %%
Quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
Qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %%
print("QuanLenght:",len(Quan))
print("QualLenght:",len(Qual))
# Out:
# QuanLenght: 7
# QualLenght: 8

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
descriptive=Univariate.UniVariate(dataset, Quan)
descriptive
# Out:
#                         sl_no       ssc_p       hsc_p   degree_p     etest_p  \
# Mean                    108.0   67.303395   66.333163  66.370186   72.100558
# Median                  108.0        67.0        65.0       66.0        71.0
# Mode                        1        62.0        63.0       65.0        60.0
# Q1:25%                   54.5        60.6        60.9       61.0        60.0
# Q2:50%                  108.0        67.0        65.0       66.0        71.0
# Q3:75%                  161.5        75.7        73.0       72.0        83.5
# 99%                    212.86        87.0       91.86      83.86        97.0
# Q4:100%                 215.0        89.4        97.7       91.0        98.0
# IQR                     107.0        15.1        12.1       11.0        23.5
# 1.5rule                 160.5       22.65       18.15       16.5       35.25
# Lesser                 -106.0       37.95       42.75       44.5       24.75
# ...

# %% [markdown]
# # Finding Outliers

# %%
Lesser, Greater = Univariate.FindingOutlier(Quan,descriptive)
print("Lesser:", Lesser)
print("Greater:", Greater)
Lesser=Lesser
Greater=Greater
# Out:
# Lesser: ['hsc_p']
# Greater: ['hsc_p', 'degree_p', 'salary']

# %% [markdown]
# # Replacing Outliers

# %%
dataset=Univariate.ReplacingOutliers(dataset, descriptive, Quan, Lesser, Greater)
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
descriptive=Univariate.UniVariate(dataset,Quan)
descriptive
# Out:
#                         sl_no       ssc_p       hsc_p   degree_p     etest_p  \
# Mean                    108.0   67.303395   66.334744  66.358558   72.100558
# Median                  108.0        67.0        65.0       66.0        71.0
# Mode                        1        62.0        63.0       65.0        60.0
# Q1:25%                   54.5        60.6        60.9       61.0        60.0
# Q2:50%                  108.0        67.0        65.0       66.0        71.0
# Q3:75%                  161.5        75.7        73.0       72.0        83.5
# 99%                    212.86        87.0      91.129      83.86        97.0
# Q4:100%                 215.0        89.4       91.15       88.5        98.0
# IQR                     107.0        15.1        12.1       11.0        23.5
# 1.5rule                 160.5       22.65       18.15       16.5       35.25
# Lesser                 -106.0       37.95       42.75       44.5       24.75
# ...

# %%
Lesser, Greater = Univariate.FindingOutlier(Quan,descriptive)
print("Lesser:", Lesser)
print("Greater:", Greater)
# Out:
# Lesser: []
# Greater: []

# %% [markdown]
# # Frequency:

# %%
#Univariate.FreqTable(ColumnName, dataset)

# %%
Univariate.FreqTable("hsc_p",dataset)
# Out:
#     Unique_Values  Frequency  Relative_Frequency  \
# 0           63.00         14            0.065116
# 1           62.00         12            0.055814
# 2           67.00          9            0.041860
# 3           60.00          9            0.041860
# 4           70.00          8            0.037209
# ..            ...        ...                 ...
# 86          65.50          1            0.004651
# 87          77.60          1            0.004651
# 88          70.20          1            0.004651
# 89          61.40          1            0.004651
# 90          61.33          1            0.004651
#
#     Cummulative_Frequency or cumsum
# 0                          0.065116
# 1                          0.120930
# 2                          0.162791
# 3                          0.204651
# 4                          0.241860
# ..                              ...
# 86                         0.981395
# 87                         0.986047
# 88                         0.990698
# ...

# %%
Univariate.FreqTable("ssc_p",dataset)
# Out:
#      Unique_Values  Frequency  Relative_Frequency  \
# 0            62.00         11            0.051163
# 1            63.00         10            0.046512
# 2            67.00          9            0.041860
# 3            73.00          9            0.041860
# 4            52.00          9            0.041860
# ..             ...        ...                 ...
# 98           55.68          1            0.004651
# 99           41.00          1            0.004651
# 100          83.33          1            0.004651
# 101          43.00          1            0.004651
# 102          80.60          1            0.004651
#
#      Cummulative_Frequency or cumsum
# 0                           0.051163
# 1                           0.097674
# 2                           0.139535
# 3                           0.181395
# 4                           0.223256
# ..                               ...
# 98                          0.981395
# 99                          0.986047
# ...

# %%
Univariate.FreqTable("degree_p",dataset)
# Out:
#     Unique_Values  Frequency  Relative_Frequency  \
# 0           65.00         20            0.093023
# 1           66.00         13            0.060465
# 2           72.00         12            0.055814
# 3           64.00         11            0.051163
# 4           58.00          9            0.041860
# ..            ...        ...                 ...
# 84          64.80          1            0.004651
# 85          56.30          1            0.004651
# 86          88.50          1            0.004651
# 87          56.87          1            0.004651
# 88          77.60          1            0.004651
#
#     Cummulative_Frequency or cumsum
# 0                          0.093023
# 1                          0.153488
# 2                          0.209302
# 3                          0.260465
# 4                          0.302326
# ..                              ...
# 84                         0.981395
# 85                         0.986047
# 86                         0.990698
# ...

# %%
Univariate.FreqTable("etest_p",dataset)
# Out:
#     Unique_Values  Frequency  Relative_Frequency  \
# 0           60.00         14            0.065116
# 1           80.00          8            0.037209
# 2           67.00          7            0.032558
# 3           75.00          7            0.032558
# 4           89.00          6            0.027907
# ..            ...        ...                 ...
# 95          87.55          1            0.004651
# 96          61.28          1            0.004651
# 97          88.56          1            0.004651
# 98          92.66          1            0.004651
# 99          91.00          1            0.004651
#
#     Cummulative_Frequency or cumsum
# 0                          0.065116
# 1                          0.102326
# 2                          0.134884
# 3                          0.167442
# 4                          0.195349
# ..                              ...
# 95                         0.981395
# 96                         0.986047
# 97                         0.990698
# ...

# %%
Univariate.FreqTable("mba_p",dataset)
# Out:
#      Unique_Values  Frequency  Relative_Frequency  \
# 0            56.70          3            0.013953
# 1            62.48          2            0.009302
# 2            64.15          2            0.009302
# 3            64.08          2            0.009302
# 4            61.29          2            0.009302
# ..             ...        ...                 ...
# 200          74.49          1            0.004651
# 201          53.62          1            0.004651
# 202          69.72          1            0.004651
# 203          60.23          1            0.004651
# 204          60.22          1            0.004651
#
#      Cummulative_Frequency or cumsum
# 0                           0.013953
# 1                           0.023256
# 2                           0.032558
# 3                           0.041860
# 4                           0.051163
# ..                               ...
# 200                         0.981395
# 201                         0.986047
# ...

# %%
Univariate.FreqTable("salary",dataset)
# Out:
#     Unique_Values  Frequency  Relative_Frequency  \
# 0        300000.0         22            0.102326
# 1        250000.0         18            0.083721
# 2        240000.0         15            0.069767
# 3        390000.0         15            0.069767
# 4        260000.0          7            0.032558
# 5        200000.0          6            0.027907
# 6        360000.0          6            0.027907
# 7        265000.0          6            0.027907
# 8        275000.0          5            0.023256
# 9        220000.0          5            0.023256
# 10       270000.0          4            0.018605
# 11       210000.0          4            0.018605
# 12       350000.0          3            0.013953
# 13       216000.0          3            0.013953
# 14       204000.0          2            0.009302
# 15       236000.0          2            0.009302
# 16       230000.0          2            0.009302
# 17       280000.0          2            0.009302
# ...
