# %% [markdown]
# 1.Importing the libraries
# -

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.io as pio
pio.renderers.default="svg"

# %%
#!pip install plotly_express==0.4.0

# %% [markdown]
# 2.Importing the dataset
# -

# %%
raw_df=pd.read_csv("Zomato Chennai Listing.csv")

# %%
raw_df
# Out:
#                                               Zomato URL  \
# 0      https://www.zomato.com/chennai/yaa-mohaideen-b...
# 1      https://www.zomato.com/chennai/sukkubhai-biriy...
# 2      https://www.zomato.com/chennai/ss-hyderabad-bi...
# 3            https://www.zomato.com/chennai/kfc-perambur
# 4      https://www.zomato.com/chennai/tasty-kitchen-p...
# ...                                                  ...
# 12027  https://www.zomato.com/chennai/cks-sandwiches-...
# 12028  https://www.zomato.com/chennai/cks-sandwiches-...
# 12029  https://www.zomato.com/chennai/cks-sandwiches-...
# 12030  https://www.zomato.com/chennai/cks-sandwiches-...
# 12031  https://www.zomato.com/chennai/cks-sandwiches-...
#
#           Name of Restaurant  \
# 0      Yaa Mohaideen Briyani
# 1         Sukkubhai Biriyani
# 2       SS Hyderabad Biryani
# 3                        KFC
# 4              Tasty Kitchen
# ...                      ...
# 12027        CK's Sandwiches
# 12028        CK's Sandwiches
# ...

# %% [markdown]
# 3.Getting Basic Information about the Dataset
# -

# %%
raw_df.shape
# Out:
# (12032, 12)

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12032 entries, 0 to 12031
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Zomato URL             12032 non-null  object
#  1   Name of Restaurant     12032 non-null  object
#  2   Address                12032 non-null  object
#  3   Location               12032 non-null  object
#  4   Cuisine                12032 non-null  object
#  5   Top Dishes             12032 non-null  object
#  6   Price for 2            12032 non-null  float64
#  7   Dining Rating          6681 non-null   float64
#  8   Dining Rating Count    11812 non-null  object
#  9   Delivery Rating        6181 non-null   float64
#  10  Delivery Rating Count  11812 non-null  object
#  11  Features               12032 non-null  object
# dtypes: float64(3), object(9)
# memory usage: 1.1+ MB

# %%
raw_df.describe()
# Out:
#         Price for 2  Dining Rating  Delivery Rating
# count  12032.000000    6681.000000      6181.000000
# mean     397.611370       3.387756         3.805290
# std      332.045938       0.558181         0.374213
# min       40.000000       0.300000         0.300000
# 25%      200.000000       3.100000         3.600000
# 50%      300.000000       3.500000         3.900000
# 75%      450.000000       3.800000         4.000000
# max     5000.000000       4.900000         4.700000

# %% [markdown]
# 4.Cleaning the Dataset
# -
#
# a.Removing the redundunt rows of data
# -

# %%
# Checking redundunt rows of data

#wrong_data=raw_df['PAGE NO']=='PAGE NO'
#raw_df[wrong_data]

# %%
## Performing Negation of the wrong dataset and then storing the correct data back in the raw_df DataFrame
## This permamnently remove the wrong data from the original dataframe

#raw_df = raw_df[~wrong_data]

# %%
# Dropping columns which are not required for further analysis

raw_df.drop(['Zomato URL'], axis=1, inplace=True)

# %%
raw_df.head()
# Out:
#       Name of Restaurant                                            Address  \
# 0  Yaa Mohaideen Briyani          336 & 338, Main Road, Pallavaram, Chennai
# 1     Sukkubhai Biriyani   New 14, Old 11/3Q, Railway Station Road, MKN ...
# 2   SS Hyderabad Biryani   98/339, Arcot Road, Opposite Gokulam Chit Fun...
# 3                    KFC   10, Periyar Nagar, 70 Feet Road, Near Sheeba ...
# 4          Tasty Kitchen   135B, SRP Colony, Peravallur, Near Perambur, ...
#
#       Location                                            Cuisine  \
# 0   Pallavaram                                        ['Biryani']
# 1      Alandur  ['Biryani', ' North Indian', ' Mughlai', ' Des...
# 2  Kodambakkam  ['Biryani', ' North Indian', ' Chinese', ' Ara...
# 3     Perambur  ['Burger', ' Fast Food', ' Finger Food', ' Bev...
# 4     Perambur  ['Chinese', ' Biryani', ' North Indian', ' Che...
#
#                                           Top Dishes  Price for 2  \
# ...

# %% [markdown]
# b.Removing the Null Records
# -

# %%
# Checking for Null records

raw_df.isnull().sum()
# Out:
# Name of Restaurant          0
# Address                     0
# Location                    0
# Cuisine                     0
# Top Dishes                  0
# Price for 2                 0
# Dining Rating            5351
# Dining Rating Count       220
# Delivery Rating          5851
# Delivery Rating Count     220
# Features                    0
# dtype: int64

# %%
# Checking for a null row

raw_df[raw_df['Dining Rating Count'].isnull()]
# Out:
#                              Name of Restaurant  \
# 1603                           Erode Amman Mess
# 2159   The Ultimate Brownie And Chocolate Place
# 2419                     Amudha Aunty's kitchen
# 2537                                 TN 03 CAFE
# 2542                                Maggi Point
# ...                                         ...
# 12027                           CK's Sandwiches
# 12028                           CK's Sandwiches
# 12029                           CK's Sandwiches
# 12030                           CK's Sandwiches
# 12031                           CK's Sandwiches
#
#                                                  Address         Location  \
# 1603    163, LB Road, SMS Building, Thiruvanmiyur, Ch...    Thiruvanmiyur
# 2159                                       Delivery Only   Sholinganallur
# 2419                                       Delivery Only   Sholinganallur
# 2537                                       Delivery Only     Tiruvottiyur
# ...

# %%
# Identifying rows where both 'Dining Rating' and 'Delivery Rating' are null
rows_to_drop = raw_df[(raw_df['Dining Rating'].isna()) & (raw_df['Delivery Rating'].isna())].index

# Dropping those rows using their indices
raw_df = raw_df.drop(index=rows_to_drop)

# To verify the rows are dropped, you can check the first few rows
raw_df.head()
# Out:
#       Name of Restaurant                                            Address  \
# 0  Yaa Mohaideen Briyani          336 & 338, Main Road, Pallavaram, Chennai
# 1     Sukkubhai Biriyani   New 14, Old 11/3Q, Railway Station Road, MKN ...
# 2   SS Hyderabad Biryani   98/339, Arcot Road, Opposite Gokulam Chit Fun...
# 3                    KFC   10, Periyar Nagar, 70 Feet Road, Near Sheeba ...
# 4          Tasty Kitchen   135B, SRP Colony, Peravallur, Near Perambur, ...
#
#       Location                                            Cuisine  \
# 0   Pallavaram                                        ['Biryani']
# 1      Alandur  ['Biryani', ' North Indian', ' Mughlai', ' Des...
# 2  Kodambakkam  ['Biryani', ' North Indian', ' Chinese', ' Ara...
# 3     Perambur  ['Burger', ' Fast Food', ' Finger Food', ' Bev...
# 4     Perambur  ['Chinese', ' Biryani', ' North Indian', ' Che...
#
#                                           Top Dishes  Price for 2  \
# ...

# %%
# Confirming all the null records are correct

raw_df.isnull().sum()
# Out:
# Name of Restaurant          0
# Address                     0
# Location                    0
# Cuisine                     0
# Top Dishes                  0
# Price for 2                 0
# Dining Rating            1800
# Dining Rating Count         0
# Delivery Rating          2300
# Delivery Rating Count       0
# Features                    0
# dtype: int64

# %% [markdown]
# c.Converting the DataTypes of numerical columns to numeric dataype
# -

# %%
# Checking for text values in the column before converting it to numeric datatype

raw_df['Delivery Rating'].value_counts()
# Out:
# Delivery Rating
# 3.9    1383
# 3.8     701
# 4.0     570
# 3.7     559
# 4.1     468
# 3.6     465
# 4.2     401
# 3.5     314
# 4.3     277
# 3.4     259
# 3.3     189
# 4.4     128
# 3.2      93
# 3.1      79
# 3.0      63
# 4.5      55
# 2.9      39
# 2.8      26
# 4.6      24
# 2.7      19
# 2.6      17
# 2.5       9
# 0.3       8
# 2.4       7
# 1.8       5
# 2.3       5
# 2.0       5
# 2.2       5
# 4.7       4
# 2.1       2
# 1.6       1
# 1.5       1
# Name: count, dtype: int64

# %%
# Replacing the text values with '0'

#raw_df['RATING'] = raw_df['RATING'].replace(['-', 'NEW', 'Opening'], '0')

# %%
# Checking for text values in the column before converting it to numeric datatype

raw_df['Dining Rating Count'].value_counts()
# Out:
# Dining Rating Count
# Does not offer Dining        1550
# 4                             339
# 5                             271
# Not enough Dining Reviews     250
# 6                             248
#                              ...
# 1302                            1
# 1267                            1
# 1620                            1
# 2405                            1
# 587                             1
# Name: count, Length: 793, dtype: int64

# %%
# Replacing the text values with '0'

raw_df['Dining Rating Count'] = raw_df['Dining Rating Count'].replace(['Does not offer Dining','Not enough Dining Reviews'], '0')

# %%
raw_df['Dining Rating Count'].value_counts()
# Out:
# Dining Rating Count
# 0       1820
# 4        339
# 5        271
# 6        248
# 8        180
#         ...
# 446        1
# 318        1
# 1893       1
# 2244       1
# 5821       1
# Name: count, Length: 791, dtype: int64

# %%
# Checking for text values in the column before converting it to numeric datatype

raw_df['Delivery Rating Count'].value_counts()
# Out:
# Delivery Rating Count
# Not enough Delivery Reviews    1217
# Does not offer Delivery        1083
# 27                               34
# 22                               30
# 60                               30
#                                ...
# 6226                              1
# 39600                             1
# 21700                             1
# 4320                              1
# 24700                             1
# Name: count, Length: 2281, dtype: int64

# %%
raw_df['Delivery Rating Count'] = raw_df['Delivery Rating Count'].replace(['Not enough Delivery Reviews', 'Does not offer Delivery'], '0')

# %%
raw_df['Delivery Rating Count'].value_counts()
# Out:
# Delivery Rating Count
# 0        2319
# 27         34
# 22         30
# 60         30
# 37         30
#          ...
# 282         1
# 885         1
# 757         1
# 1789        1
# 24700       1
# Name: count, Length: 2279, dtype: int64

# %%
# Changing Data Type of the numerical columns

raw_df['Dining Rating Count'] = raw_df['Dining Rating Count'].astype('int64')
raw_df['Delivery Rating Count'] = raw_df['Delivery Rating Count'].astype('int64')

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8481 entries, 0 to 11960
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name of Restaurant     8481 non-null   object
#  1   Address                8481 non-null   object
#  2   Location               8481 non-null   object
#  3   Cuisine                8481 non-null   object
#  4   Top Dishes             8481 non-null   object
#  5   Price for 2            8481 non-null   float64
#  6   Dining Rating          6681 non-null   float64
#  7   Dining Rating Count    8481 non-null   int64
#  8   Delivery Rating        6181 non-null   float64
#  9   Delivery Rating Count  8481 non-null   int64
#  10  Features               8481 non-null   object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 795.1+ KB

# %%
raw_df
# Out:
#           Name of Restaurant  \
# 0      Yaa Mohaideen Briyani
# 1         Sukkubhai Biriyani
# 2       SS Hyderabad Biryani
# 3                        KFC
# 4              Tasty Kitchen
# ...                      ...
# 11901       Dhabba On Wheels
# 11914       Sandwich Sisters
# 11953       The Sandwich Box
# 11959      The Shangai Story
# 11960      The Shangai Story
#
#                                                  Address     Location  \
# 0              336 & 338, Main Road, Pallavaram, Chennai   Pallavaram
# 1       New 14, Old 11/3Q, Railway Station Road, MKN ...      Alandur
# 2       98/339, Arcot Road, Opposite Gokulam Chit Fun...  Kodambakkam
# 3       10, Periyar Nagar, 70 Feet Road, Near Sheeba ...     Perambur
# 4       135B, SRP Colony, Peravallur, Near Perambur, ...     Perambur
# ...                                                  ...          ...
# 11901   5/336, Old Mahabalipuram Road, Okkiyampet, Ch...   Okkiyampet
# ...

# %% [markdown]
# d.Working with 'Timing' column
# -

# %%
#raw_df['TIMING'].value_counts()

# %%
# Splitting the column and storing it in temp_df dataframe

#temp_df = raw_df['TIMING'].str.split("(", n=1, expand=True)
#temp_df

# %%
#Assigning the columns back to the raw_df dataframe

#raw_df['TIMING'] = temp_df[0]
#raw_df['DAYS_OPEN'] = temp_df[1]
#raw_df.head()

# %%
# Removing the closing bracket character ')' from the 'DAYS_OPEN' column

#raw_df['DAYS_OPEN'] = raw_df['DAYS_OPEN'].str.replace(')', '', regex=False)

#raw_df.head()

# %%
# Checking for Null records in DAYS_OPEN column
raw_df.isnull().sum()
# Out:
# Name of Restaurant          0
# Address                     0
# Location                    0
# Cuisine                     0
# Top Dishes                  0
# Price for 2                 0
# Dining Rating            1800
# Dining Rating Count         0
# Delivery Rating          2300
# Delivery Rating Count       0
# Features                    0
# dtype: int64

# %%
# Replace Null values in 'Dining Rating' and 'Delivery Rating' columns with 0
raw_df['Dining Rating'].fillna(0, inplace=True)
raw_df['Delivery Rating'].fillna(0, inplace=True)

# To verify if the Null values are replaced
print(raw_df[['Dining Rating', 'Delivery Rating']].head())
# Out:
#    Dining Rating  Delivery Rating
# 0            4.3              4.3
# 1            4.4              4.1
# 2            4.3              4.4
# 3            4.0              4.0
# 4            4.2              4.1
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_3536\1844824216.py:2: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_3536\1844824216.py:3: FutureWarning:
#
# ...

# %%
# Replacing the Null values with 'NA'
raw_df.fillna('NA', inplace=True)

# %%
# Checking info of all the columns
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8481 entries, 0 to 11960
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name of Restaurant     8481 non-null   object
#  1   Address                8481 non-null   object
#  2   Location               8481 non-null   object
#  3   Cuisine                8481 non-null   object
#  4   Top Dishes             8481 non-null   object
#  5   Price for 2            8481 non-null   float64
#  6   Dining Rating          8481 non-null   float64
#  7   Dining Rating Count    8481 non-null   int64
#  8   Delivery Rating        8481 non-null   float64
#  9   Delivery Rating Count  8481 non-null   int64
#  10  Features               8481 non-null   object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 795.1+ KB

# %% [markdown]
# e.Removing the restaurant records whose Rating or Votes is 0
# -

# %%
# Finding those restaurant whose having 0 Rating or Votes

#useless_data = (raw_df['RATING'] == 0.0) | (raw_df['VOTES'] == 0)
#raw_df[useless_data]

# %%
## Performing Negation of the useless dataset and then storing the correct data back in the raw_df DataFrame
## This permamnently remove the wrong data from the original dataframe
#raw_df = raw_df[~useless_data]

# %% [markdown]
# f. Working on 'RATING_TYPE' Column
# -

# %%
# Checking the unique values in the column
#raw_df['RATING_TYPE'].value_counts()

# %%
# Translating the texts into proper English text

'''
raw_df['RATING_TYPE'] = raw_df['RATING_TYPE'].replace('Excelente', 'Excellent')
raw_df['RATING_TYPE'] = raw_df['RATING_TYPE'].replace(['Veľmi dobré','Bardzo dobrze','Muy Bueno','Velmi dobré'], 'Very Good')
raw_df['RATING_TYPE'] = raw_df['RATING_TYPE'].replace(['Skvělá volba','Dobrze','Bueno','Buono','Dobré','Bom','Skvělé'], 'Good')
raw_df['RATING_TYPE'] = raw_df['RATING_TYPE'].replace(['Priemer','Média','Çok iyi'], 'Average')
raw_df['RATING_TYPE'] = raw_df['RATING_TYPE'].replace(['Průměr','Promedio','Ortalama','Muito Bom','İyi'], 'Poor')
raw_df['RATING_TYPE'] = raw_df['RATING_TYPE'].replace(['Baik','Biasa','Media','Sangat Baik'], 'Very Poor')
'''
# Out:
# "\nraw_df['RATING_TYPE'] = raw_df['RATING_TYPE'].replace('Excelente', 'Excellent')\nraw_df['RATING_TYPE'] = raw_df['RATING_TYPE'].replace(['Veľmi dobré','Bardzo dobrze','Muy Bueno','Velmi dobré'], 'Very Good')\nraw_df['RATING_TYPE'] = raw_df['RATING_TYPE'].replace(['Skvělá volba','Dobrze','Bueno','Buono','Dobré','Bom','Skvělé'], 'Good')\nraw_df['RATING_TYPE'] = raw_df['RATING_TYPE'].replace(['Priemer','Média','Çok iyi'], 'Average')\nraw_df['RATING_TYPE'] = raw_df['RATING_TYPE'].replace(['Průměr','Promedio','Ortalama','Muito Bom','İyi'], 'Poor')\nraw_df['RATING_TYPE'] = raw_df['RATING_TYPE'].replace(['Baik','Biasa','Media','Sangat Baik'], 'Very Poor')\n"

# %%
# Checking all the values correctly mapped
#raw_df['RATING_TYPE'].value_counts()

# %% [markdown]
# g.Working on 'REGION' Column
# -

# %%
#raw_df['REGION'].value_counts()

# %%
# Removing the irrelevant text from the Region column
#raw_df['REGION'] = raw_df['REGION'].str.replace('[a-zA-Z].+-- ','',regex=True)

# %%
# Removing the West & East from the Region column
#raw_df['REGION'] = raw_df['REGION'].str.replace('West| west| East| east', '', regex=True)

# %%
raw_df['Location'].value_counts()
# Out:
# Location
# Porur                                                       270
# Velachery                                                   255
# T. Nagar                                                    235
# Anna Nagar East                                             227
# Ambattur                                                    213
#                                                            ...
# Hotel Goutham Manor, Nungambakkam                             1
# Vivira Mall, Navallur                                         1
# Hotel Anitha Towers, Triplicane                               1
# RMZ Millenia Business Park, Old Mahabalipuram Road (OMR)      1
# Chandra Metro Mall, Virugambakkam                             1
# Name: count, Length: 264, dtype: int64

# %%
# total_unique_locations = raw_df['Location'].nunique()
# print("Total unique locations:", total_unique_locations)

# %%
# Split the 'Location' column by comma and take the part after the last comma
# Vivira Mall, Navallur to Navallur
raw_df['Location'] = raw_df['Location'].str.split(',').str[-1].str.strip()

# Verify the changes by checking the first few rows
raw_df.head()
# Out:
#       Name of Restaurant                                            Address  \
# 0  Yaa Mohaideen Briyani          336 & 338, Main Road, Pallavaram, Chennai
# 1     Sukkubhai Biriyani   New 14, Old 11/3Q, Railway Station Road, MKN ...
# 2   SS Hyderabad Biryani   98/339, Arcot Road, Opposite Gokulam Chit Fun...
# 3                    KFC   10, Periyar Nagar, 70 Feet Road, Near Sheeba ...
# 4          Tasty Kitchen   135B, SRP Colony, Peravallur, Near Perambur, ...
#
#       Location                                            Cuisine  \
# 0   Pallavaram                                        ['Biryani']
# 1      Alandur  ['Biryani', ' North Indian', ' Mughlai', ' Des...
# 2  Kodambakkam  ['Biryani', ' North Indian', ' Chinese', ' Ara...
# 3     Perambur  ['Burger', ' Fast Food', ' Finger Food', ' Bev...
# 4     Perambur  ['Chinese', ' Biryani', ' North Indian', ' Che...
#
#                                           Top Dishes  Price for 2  \
# ...

# %%
raw_df['Location'].value_counts()
# Out:
# Location
# Velachery          303
# Porur              273
# T. Nagar           253
# Ambattur           239
# Anna Nagar East    227
#                   ...
# Perumbakkam          2
# East...              1
# The Slate            1
# Oragadam             1
# Kanchipuram          1
# Name: count, Length: 128, dtype: int64

# %%
# Replacing Small regions with Known region name
# raw_df['REGION'] = raw_df['REGION'].str.replace('4 Bungalows|7 Andheri|Azad Nagar|Near Andheri Station|Veera Desai Area', 'Andheri', regex=True)
# raw_df['REGION'] = raw_df['REGION'].str.replace('Bandra Kurla Complex','Bandra',regex=True)
# raw_df['REGION'] = raw_df['REGION'].str.replace('CBD-Belapur','CBD Belapur',regex=True)
# raw_df['REGION'] = raw_df['REGION'].str.replace('Girgaon Chowpatty','Chowpatty',regex=True)
# raw_df['REGION'] = raw_df['REGION'].str.replace('Dadar Shivaji Park','Dadar',regex=True)
# raw_df['REGION'] = raw_df['REGION'].str.replace('Flea Bazaar Café|Kamala Mills Compound','Lower Parel',regex=True)
# raw_df['REGION'] = raw_df['REGION'].str.replace('Runwal Green','Mulund',regex=True)
# raw_df['REGION'] = raw_df['REGION'].str.replace('Mumbai CST Area','Mumbai Central',regex=True)
# raw_df['REGION'] = raw_df['REGION'].str.replace('Kopar Khairane|Seawoods|Turbhe|Ulwe','Navi Mumbai',regex=True)
# raw_df['REGION'] = raw_df['REGION'].str.replace('New Panvel|Old Panvel','Panvel',regex=True)
# raw_df['REGION'] = raw_df['REGION'].str.replace('Kamothe','Sion',regex=True)
# raw_df['REGION'] = raw_df['REGION'].str.replace('Ghodbunder Road|Majiwada','Thane',regex=True)

# %% [markdown]
# h.Removing Duplicate records
# -

# %%
# Finding all the duplicate rows

raw_df[raw_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Name of Restaurant, Address, Location, Cuisine, Top Dishes, Price for 2, Dining Rating, Dining Rating Count, Delivery Rating, Delivery Rating Count, Features]
# Index: []

# %%
# Dropping all the duplicate rows
#raw_df = raw_df.drop_duplicates()

# %% [markdown]
# 4.Copying the cleaned data into a new DataFrame
# -

# %%
raw_df.isnull().sum()
# Out:
# Name of Restaurant       0
# Address                  0
# Location                 0
# Cuisine                  0
# Top Dishes               0
# Price for 2              0
# Dining Rating            0
# Dining Rating Count      0
# Delivery Rating          0
# Delivery Rating Count    0
# Features                 0
# dtype: int64

# %%
zomato_df = raw_df.copy()

# %%
zomato_df.head()
# Out:
#       Name of Restaurant                                            Address  \
# 0  Yaa Mohaideen Briyani          336 & 338, Main Road, Pallavaram, Chennai
# 1     Sukkubhai Biriyani   New 14, Old 11/3Q, Railway Station Road, MKN ...
# 2   SS Hyderabad Biryani   98/339, Arcot Road, Opposite Gokulam Chit Fun...
# 3                    KFC   10, Periyar Nagar, 70 Feet Road, Near Sheeba ...
# 4          Tasty Kitchen   135B, SRP Colony, Peravallur, Near Perambur, ...
#
#       Location                                            Cuisine  \
# 0   Pallavaram                                        ['Biryani']
# 1      Alandur  ['Biryani', ' North Indian', ' Mughlai', ' Des...
# 2  Kodambakkam  ['Biryani', ' North Indian', ' Chinese', ' Ara...
# 3     Perambur  ['Burger', ' Fast Food', ' Finger Food', ' Bev...
# 4     Perambur  ['Chinese', ' Biryani', ' North Indian', ' Che...
#
#                                           Top Dishes  Price for 2  \
# ...

# %% [markdown]
# 5.Performing Exploratory Data Analysis
# -
#
# Q1) How many restaurants are in Chennai for different location?
# -

# %%
fig = px.histogram(zomato_df, x='Location', color='Location',
                   title='No. of restaurants by Location',
                   labels={'Location': 'Location'})

fig.show()

# %%
#!pip install -U kaleido

# %% [markdown]
# Q2)What are the number of restaurants by Rating Type in Chennai?
# -

# %%
# Define the bins and labels for grouping
bins = [0, 2, 3, 4, 5]
labels = ['0-2', '2-3', '3-4', '4-5']

# Apply the pd.cut() function to create the groups
zomato_df['Dining Rating Group'] = pd.cut(zomato_df['Dining Rating'], bins=bins, labels=labels, include_lowest=True)

# Now, you can count the occurrences in each group
grouped_data = zomato_df['Dining Rating Group'].value_counts().sort_index()

# View the grouped data
print(grouped_data)

# You can then plot this data using a bar graph
import matplotlib.pyplot as plt

grouped_data.plot(kind='bar', color='skyblue', title='Number of Restaurants by Dining Rating Groups')
plt.xlabel('Dining Rating Group')
plt.ylabel('Count of Restaurants')
plt.show()
# Out:
# Dining Rating Group
# 0-2    2161
# 2-3    1167
# 3-4    4548
# 4-5     605
# Name: count, dtype: int64

# %%
# rating_type_df = zomato_df['RATING_TYPE'].value_counts()

# # Rename the index and name of the Series
# rating_type_df.rename(index=str, inplace=True)  # Just to ensure index is string
# rating_type_df.index.name = 'RATING TYPE'  # Rename index as 'RATING TYPE'
# rating_type_df.name = 'COUNT OF RESTAURANTS'  # Rename the Series name (counts column)

# # rating_type_df

# %%
# # Convert the Series to a DataFrame
# rating_type_df = rating_type_df.reset_index()

# # Rename the columns appropriately
# rating_type_df.columns = ['RATING TYPE', 'COUNT OF RESTAURANTS']

# # Now plot using Plotly
# fig = px.pie(rating_type_df, names='RATING TYPE', values='COUNT OF RESTAURANTS', 
#              color='RATING TYPE', title='Percentage of Restaurants by Rating Type').update_traces(textposition='inside', textinfo='percent+label')

# fig.show()

# %% [markdown]
# Q3.Which are the Top 10 highest rated Biryani Restaurant in Chennai?
# -

# %%
biryani_df = zomato_df[zomato_df['Top Dishes'].str.contains('Biryani')]
biryani_df.sort_values(by='Dining Rating', ascending=False). head(10)
# Out:
#                                 Name of Restaurant  \
# 195                                     The Marina
# 187                   J.Hind - Grand by GRT Hotels
# 173                               Bombay Brasserie
# 116                                         AlMaza
# 470                  New Pattukottai Kamatchi Mess
# 199                           Arabian Kebab Center
# 9232                               Barbeque Nation
# 8757                         Yaa Mohaideen Biryani
# 9037                                     Palmshore
# 85    Bazaar - All Day Diner - Grand by GRT Hotels
#
#                                                 Address             Location  \
# 195             39, College Road, Nungambakkam, Chennai         Nungambakkam
# 187    Grand by GRT Hotels, 120, Sir Thyagaraya Road...  Grand by GRT Hotels
# 173              3, College Lane, Nungambakkam, Chennai         Nungambakkam
# 116    30, A Block, 6th Street, Near Titan Showroom,...      Anna Nagar East
# ...

# %% [markdown]
# Q4.Which is the best South Indian Cuisine?
# -

# %%
foodtruck_df = zomato_df[zomato_df['Cuisine'].str.contains('South Indian')]
foodtruck_df.sort_values(by='Dining Rating Count',ascending=False).head(2)
# Out:
#             Name of Restaurant  \
# 172             Animal Kingdom
# 171  Grill Box - Unlimited BBQ
#
#                                                Address  Location  \
# 172   44, 1st Main Road, Near Fortis Hospital, Adya...     Adyar
# 171      25, Dr Radhakrishnan Salai, Mylapore, Chennai  Mylapore
#
#                                                Cuisine  \
# 172  ['North Indian', ' Chinese', ' Continental', '...
# 171  ['North Indian', ' South Indian', ' BBQ', ' De...
#
#                                             Top Dishes  Price for 2  \
# 172  ['Gulab Jamun', ' Momos', ' Elaneer Payasam', ...       1300.0
# 171  ['Momos', ' Chicken Wings', ' Cotton Candy', '...       1200.0
#
#      Dining Rating  Dining Rating Count  Delivery Rating  \
# 172            4.1                 2733              3.9
# 171            4.4                 2492              0.0
#
#      Delivery Rating Count                                           Features  \
# ...

# %% [markdown]
# Q5) Which places have the highest rated restaurant for each Cuisine Type in Chennai?
# -

# %%
# Assuming restaurants having rating above 4.5
highest_rated_df = zomato_df[zomato_df['Dining Rating'] >= 4.8]
highest_rated_df
# Out:
#                      Name of Restaurant  \
# 57                       Brownie Heaven
# 62   Amadora Gourmet Ice Cream & Sorbet
# 105                             Bhangra
# 155                   The Sandwich Shop
# 163    Momo Sa-Khang by Kailash Kitchen
# 184                Gossip Fusion Bistro
# 192                        Kabab Corner
# 195                          The Marina
# 219               Prems Graama Bhojanam
# 320                        Bombay Kulfi
# 443          Avartana - ITC Grand Chola
#
#                                                Address       Location  \
# 57    193, Peters Road, Opposite New College, Royap...     Royapettah
# 62    23, Wallace Garden, 3rd Street, Nungambakkam,...   Nungambakkam
# 105              Mayajaal Multiplex, Kanathur, Chennai       Kanathur
# 155            1, Subba Street, West Mambalam, Chennai  West Mambalam
# 163   2/247, Perinbavilas Complex, Opposite Chitra ...    Choolaimedu
# ...

# %%
fig = px.histogram(highest_rated_df, x='Location', color='Name of Restaurant',
title= 'No. of Best Restaurant for each Cuisine by Places').update_xaxes(categoryorder="total descending")
fig.show()

# %% [markdown]
# Q6) What is the Avg Price Distibution of highest rated restaurant for each Cuisine Type in Chennai?
# -

# %%
highest_rated_price_df = highest_rated_df.groupby(by=['Name of Restaurant', 'Location', 'Cuisine'])['Price for 2'].mean().reset_index()
highest_rated_price_df.head()
# Out:
#                    Name of Restaurant      Location  \
# 0  Amadora Gourmet Ice Cream & Sorbet  Nungambakkam
# 1          Avartana - ITC Grand Chola        Guindy
# 2                             Bhangra      Kanathur
# 3                        Bombay Kulfi         Adyar
# 4                      Brownie Heaven    Royapettah
#
#                                      Cuisine  Price for 2
# 0                 ['Desserts', ' Ice Cream']        500.0
# 1  ['South Indian', ' Chinese', ' Desserts']       4500.0
# 2                           ['North Indian']        800.0
# 3                              ['Ice Cream']        200.0
# 4      ['Bakery', ' Desserts', ' Beverages']        350.0

# %%
fig = px.scatter(highest_rated_price_df, x="Location", y="Price for 2", color="Cuisine", symbol="Cuisine",
title=' Avg Price Distibution of High rated restaurant for each Cuisine Type').update_traces(marker_size=10)
fig.show()

# %% [markdown]
# Q7)Which Location have a large number of Chinese Restaurant Market?
# -

# %%
chinese_df = zomato_df[zomato_df['Cuisine'].str.contains('Chinese')]
chinese_df
# Out:
#              Name of Restaurant  \
# 2          SS Hyderabad Biryani
# 4                 Tasty Kitchen
# 5                    Dine N Fun
# 8             Savoury Sea Shell
# 9      Sangeetha Veg Restaurant
# ...                         ...
# 11883              Hotel Rahman
# 11886              Hotel Rahman
# 11887              Hotel Rahman
# 11959         The Shangai Story
# 11960         The Shangai Story
#
#                                                  Address  \
# 2       98/339, Arcot Road, Opposite Gokulam Chit Fun...
# 4       135B, SRP Colony, Peravallur, Near Perambur, ...
# 5       Opposite Forest Office, Tambaram Main Road, S...
# 8       3, E Block, 3rd Avenue, Anna Nagar East, Chennai
# 9              102/82, GN Chetty Road, T. Nagar, Chennai
# ...                                                  ...
# 11883   221, Central Avenue Road, Mahindra World City...
# 11886   4/548, Velachery Main Road, Senthamil Nagar, ...
# ...

# %%
# Grouping by 'Location' and aggregating 'Name of Restaurant' count and 'Price for 2' mean
chinese_rest_df = chinese_df.groupby(by='Location').agg({'Name of Restaurant': 'count', 'Price for 2': 'mean'}).rename(columns={'Name of Restaurant': 'COUNT OF RESTAURANTS'})

# Sorting the DataFrame by 'COUNT OF RESTAURANTS' in descending order and taking the top 25
chinese_rest_df = chinese_rest_df.sort_values('COUNT OF RESTAURANTS', ascending=False).head(25)

# Displaying the first few rows of the resulting DataFrame
chinese_rest_df.head()
# Out:
#            COUNT OF RESTAURANTS  Price for 2
# Location
# Porur                        93   453.225806
# Ambattur                     87   401.149425
# T. Nagar                     85   550.588235
# Velachery                    82   557.317073
# Perambur                     76   434.210526

# %%
# Resetting the index to convert REGION from index to a column
chinese_rest_df = chinese_rest_df.reset_index()

# Creating a bar plot with REGION on the x-axis and COUNT OF RESTAURANTS on the y-axis
fig = px.bar(chinese_rest_df, x='Location', y='COUNT OF RESTAURANTS', color='Price for 2', 
             title='No. of Chinese Restaurants by Places')

# Showing the plot
fig.show()

# %% [markdown]
# Q8) Is there a relation between Price and Rating by each Cuisine Type?
# -

# %%
price_rating_df = zomato_df.groupby(['Cuisine', 'Dining Rating'])['Price for 2'].mean().reset_index()
price_rating_df

# Grouping by 'Cuisine' and 'Dining Rating', then calculating the mean of 'Price for 2'
price_rating_df = zomato_df.groupby(['Cuisine', 'Dining Rating'])['Price for 2'].mean().reset_index()

# Filtering for 'Dining Rating' greater than 4
price_rating_df = price_rating_df[price_rating_df['Dining Rating'] > 4]

# Displaying the resulting DataFrame
price_rating_df
# Out:
#                                                 Cuisine  Dining Rating  \
# 2     ['American', ' Continental', ' Italian', ' Nor...            4.1
# 3                          ['American', ' Continental']            4.1
# 10    ['American', ' Mexican', ' Steak', ' Beverages...            4.4
# 17              ['Andhra', ' Biryani', ' North Indian']            4.2
# 29    ['Andhra', ' Chinese', ' North Indian', ' Sout...            4.2
# ...                                                 ...            ...
# 4495                                           ['Thai']            4.7
# 4496                  ['Tibetan', ' Chinese', ' Momos']            4.1
# 4498                            ['Tibetan', ' Chinese']            4.2
# 4499  ['Tibetan', ' Mexican', ' North Indian', ' Chi...            4.1
# 4508                              ['Turkish', ' Kebab']            4.3
#
#       Price for 2
# 2           800.0
# 3          1600.0
# 10         1600.0
# 17          500.0
# ...

# %%
fig = px.line(price_rating_df, y="Price for 2", x="Dining Rating",color='Cuisine')
fig.show()

# %% [markdown]
# Q9) Is there a relation between Region and Price?
# -

# %%
region_price_df = zomato_df.groupby(['Location'])['Price for 2'].mean().reset_index()
region_price_df
# Out:
#           Location  Price for 2
# 0    A Radha Hotel  1900.000000
# 1    Abhiramapuram   230.000000
# 2       Adambakkam   306.790123
# 3            Adyar   476.708075
# 4          Akkarai   768.181818
# ..             ...          ...
# 123         Vepery   303.571429
# 124   Vettuvankeni   568.750000
# 125  Virugambakkam   377.358491
# 126   Washermenpet   340.909091
# 127  West Mambalam   273.673469
#
# [128 rows x 2 columns]

# %%
fig = px.scatter(region_price_df, x='Location', y='Price for 2').update_traces(marker_size=8)
fig.show()

# %% [markdown]
# Q10) Find the list of Affordable Restaurants?
# -
# The criteria for Affordable Restaurants would be:-
# 1) Low Price
# 2) High Rated
# First step will be to find the restaurants with average cost 1/4th the average cost of most expensive restaurant in our datafr
# ame.
# Let me explain:-The most expensive restaurant has an average meal cost= 6000. We'll try to stay economical and only pick the
# restaurants that are 1/4th of 6000.

# %%
max_price = zomato_df['Price for 2'].max()
one_fourth_price = max_price/4
one_fourth_price
# Out:
# np.float64(1250.0)

# %%
# Finding list of restaurants that have price less than and equal to 1/4th of the max price i.e Finding Cheap Restauran
aff_rest_df = zomato_df[['Name of Restaurant', 'Price for 2', 'Cuisine', 'Location']]
aff_rest_df = aff_rest_df[aff_rest_df['Price for 2'] <= 1250]
aff_rest_df.sort_values(by='Price for 2', inplace=True)
aff_rest_df
# Out:
#                  Name of Restaurant  Price for 2  \
# 4685                       Soda Hub         40.0
# 1448                     Mamee Soup         60.0
# 4825                  Anbu Unavagam        100.0
# 108                    Rayar's Mess        100.0
# 2860       Thirunelveli Halwa Stall        100.0
# ...                             ...          ...
# 3179  Lava Bar at Metro Grand Hotel       1200.0
# 1171   Kapi Multicuisine Restaurant       1200.0
# 1166            The Roof Top Lounge       1200.0
# 383              Broken Bridge Cafe       1200.0
# 382                        Wok Monk       1200.0
#
#                                             Cuisine               Location
# 4685                                  ['Beverages']               Navallur
# 1448                               ['Healthy Food']          West Mambalam
# 4825                               ['South Indian']              Velachery
# ...

# %%
# Finding the highest rated list of restaurants
highrate_rest_df = zomato_df[['Name of Restaurant', 'Price for 2', 'Cuisine', 'Location', 'Dining Rating']]
highrate_rest_df = highrate_rest_df[highrate_rest_df['Dining Rating'] >= 4.5]
highrate_rest_df.sort_values(by='Price for 2', inplace=True)
highrate_rest_df
# Out:
#                             Name of Restaurant  Price for 2  \
# 108                               Rayar's Mess        100.0
# 178                        Royal Sandwich Shop        150.0
# 50                                 Andhikkadai        200.0
# 154                                  Nair Mess        200.0
# 320                               Bombay Kulfi        200.0
# ..                                         ...          ...
# 445  Dakshin - Crowne Plaza Chennai Adyar Park       2500.0
# 395            Southern Spice - Taj Coromandel       3000.0
# 229                   Vasco's - Hilton Chennai       3400.0
# 443                 Avartana - ITC Grand Chola       4500.0
# 303                 Peshawri - ITC Grand Chola       4500.0
#
#                                         Cuisine      Location  Dining Rating
# 108                            ['South Indian']      Mylapore            4.7
# 178    ['Fast Food', ' Desserts', ' Beverages']      Alwarpet            4.7
# ...

# %% [markdown]
# Now, we'll merge the aff_rest_df with highrate_rest_df to obtain the intersection i.e the list of Affordable Restaurants !!

# %%
highrate_aff_df = pd.merge(aff_rest_df, highrate_rest_df, how='inner', on=['Name of Restaurant', 'Location'])
highrate_aff_df = highrate_aff_df[['Name of Restaurant', 'Price for 2_x', 'Cuisine_x', 'Location']]
highrate_aff_df.rename(columns={'Name of Restaurant':'Name of Restaurant', 'Price for 2_x':'Price for 2',
'Location':'Location', 'Cuisine_x':'Cuisine'},inplace=True)

# %%
# Affordable Restaurants with low price and high rating
highrate_aff_df
# Out:
#                     Name of Restaurant  Price for 2  \
# 0                         Rayar's Mess        100.0
# 1                  Royal Sandwich Shop        150.0
# 2                  Royal Sandwich Shop        150.0
# 3                  Royal Sandwich Shop        150.0
# 4                          Andhikkadai        200.0
# 5                         Bombay Kulfi        200.0
# 6                         Bombay Kulfi        200.0
# 7                            Nair Mess        200.0
# 8                       Eating Circles        250.0
# 9                         Shree Mithai        300.0
# 10                       Welcome Hotel        300.0
# 11                   The Sandwich Shop        300.0
# 12                                  ID        300.0
# 13                         Cream Stone        350.0
# 14                         Cream Stone        350.0
# 15    Momo Sa-Khang by Kailash Kitchen        350.0
# 16           Fruit Shop On Greams Road        350.0
# ...

# %% [markdown]
# Q10) Find the list of most Reliable Restaurants?
# -
# The criteria for most Reliable Restaurants would be:-
# 1) Low Price
# 2) High Rated
# 3) Large No. of Votes
#
# First step will be to find the restaurants with Votes greater than Mean of Votes

# %%
mean_votes = zomato_df['Dining Rating'].mean()
mean_votes
# Out:
# np.float64(2.6687418936446177)

# %%
# Finding list of restaurants that have Votes greater than and equal to Mean of Vote
mean_rest_df = zomato_df[['Name of Restaurant', 'Price for 2', 'Cuisine', 'Location', 'Dining Rating']]
mean_rest_df = mean_rest_df[mean_rest_df['Dining Rating'] > 2.66]
mean_rest_df.sort_values(by='Dining Rating', inplace=True)
mean_rest_df
# Out:
#               Name of Restaurant  Price for 2  \
# 3039            Shaik Shack Eats        300.0
# 3068   Arabian Oyster Restaurant        450.0
# 11458         Sri Krishna Bhavan        400.0
# 3839              Hotel Shalimar        400.0
# 2951              Prince Briyani        250.0
# ...                          ...          ...
# 192                 Kabab Corner        450.0
# 219        Prems Graama Bhojanam        500.0
# 155            The Sandwich Shop        300.0
# 105                      Bhangra        800.0
# 57                Brownie Heaven        350.0
#
#                                         Cuisine       Location  Dining Rating
# 3039   ['Fast Food', ' Lebanese', ' Beverages']       T. Nagar            2.7
# 3068               ['North Indian', ' Chinese']    Maduravoyal            2.7
# 11458                          ['South Indian']      Velachery            2.7
# 3839                           ['South Indian']      Velachery            2.7
# ...

# %% [markdown]
# These are the most reliable, highest rated and affordable restaurants
# -
# We obtain this dataframe by simply taking the intersection of highrate_aff_df & mean_rest_df
#
# This dataframe obtained below shows the restaurants whose:
#
# Cost is below 1250
#
# Rating is above 2.66

# %%
reliable_rest_df = pd.merge(mean_rest_df, highrate_aff_df, how='inner', on=['Name of Restaurant', 'Location'])
reliable_rest_df = reliable_rest_df[['Name of Restaurant', 'Price for 2_x', 'Location', 'Cuisine_x']]
reliable_rest_df.rename(columns={'Name of Restaurant':'Name of Restaurant', 'Price for 2_x':'Price for 2',
'Location':'Location', 'Cusine_x':'Cusine'},inplace=True)

reliable_rest_df
# Out:
#                     Name of Restaurant  Price for 2  \
# 0                  Royal Sandwich Shop        150.0
# 1                  Royal Sandwich Shop        150.0
# 2                  Royal Sandwich Shop        150.0
# 3                  Royal Sandwich Shop        150.0
# 4                  Royal Sandwich Shop        150.0
# 5                  Royal Sandwich Shop        150.0
# 6                Yaa Mohaideen Biryani        600.0
# 7                        Welcome Hotel        300.0
# 8                          Cream Stone        350.0
# 9                           Ratna Cafe        400.0
# 10               Shri Rajasthani Dhaba        500.0
# 11                     Blind Ch3mistry        700.0
# 12                           BurgerMan        450.0
# 13                         Flower Drum        800.0
# 14  Shmoozie's Hand-Crafted Ice Creams        400.0
# 15                       Absolute Thai       1000.0
# 16                                  ID        300.0
# ...
